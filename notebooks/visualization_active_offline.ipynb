# %%
import os
import sys
import glob
import pickle
import yaml
from tqdm import tqdm
import itertools


import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

# %%
sys.path.append("..")

# %%
import metrics
import utils

# %%
SAVE = False

# %%
#results_dir = "../results/small/active"
results_dir = "../results/active"

# %%
config_files = glob.glob(f"{results_dir}/*/*/*.yaml")
config_files
# Out:
# ['../results/active/clova_2022-02-13/04-01-17/config_clova_2sec_score_cos_sc_avg.yaml',
#  '../results/active/clova_2022-02-13/05-47-05/config_clova_2sec_score_plda_sph.yaml',
#  '../results/active/speechbrain_2022-02-13/03-38-42/config_speechbrain_trimmed_2sec_score_cos_sc_avg.yaml',
#  '../results/active/speechbrain_2022-02-13/05-13-09/config_speechbrain_trimmed_2sec_score_plda_sph.yaml',
#  '../results/active/xvector_2022-02-12/23-36-43/config_xvector_trimmed_2sec_score_plda_diag.yaml',
#  '../results/active/xvector_2022-02-12/02-36-17/config_xvector_trimmed_2sec_plda_diag_offline_ahc_plda_sph.yaml',
#  '../results/active/xvector_2022-02-12/23-06-49/config_xvector_trimmed_2sec_plda_diag_offline_kmeans.yaml',
#  '../results/active/speechbrain_2022-02-12/01-45-26/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_vb_plda_sph.yaml',
#  '../results/active/speechbrain_2022-02-12/23-29-57/config_speechbrain_trimmed_2sec_cos_emb_avg.yaml',
#  '../results/active/speechbrain_2022-02-12/05-31-40/config_speechbrain_trimmed_2sec_score_cos_sc_avg.yaml',
#  '../results/active/speechbrain_2022-02-12/07-24-25/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_label_spread.yaml',
#  '../results/active/speechbrain_2022-02-12/00-21-28/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_ahc_plda_sph.yaml',
#  '../results/active/speechbrain_2022-02-11/16-49-25/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_ahc_plda_sph.yaml',
#  '../results/active/speechbrain_2022-02-11/23-31-34/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_kmeans.yaml',
#  '../results/active/speechbrain_2022-02-11/16-50-32/config_speechbrain_trimmed_2sec_score_cos_sc_avg.yaml',
#  '../results/active/speechbrain_2022-02-11/23-31-26/config_speechbrain_trimmed_2sec_cos_emb_avg.yaml',
#  '../results/active/speechbrain_2022-02-11/16-49-42/config_speechbrain_trimmed_2sec_cos_emb_avg.yaml',
#  '../results/active/speechbrain_2022-02-11/16-49-30/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_kmeans.yaml',
#  '../results/active/speechbrain_2022-02-11/16-49-56/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_vb_plda_sph.yaml',
#  '../results/active/speechbrain_2022-02-11/16-50-44/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_label_spread.yaml',
#  '../results/active/speechbrain_2022-02-11/16-50-57/config_speechbrain_trimmed_2sec_score_plda_sph.yaml',
#  '../results/active/xvector_2022-02-11/16-56-47/config_xvector_trimmed_2sec_plda_diag_offline_vb_plda_sph.yaml',
#  '../results/active/xvector_2022-02-11/17-00-33/config_xvector_trimmed_2sec_score_plda_diag_by-the-book.yaml',
#  '../results/active/xvector_2022-02-11/16-54-09/config_xvector_trimmed_2sec_plda_diag_offline_kmeans.yaml',
#  '../results/active/xvector_2022-02-11/16-58-38/config_xvector_trimmed_2sec_score_plda_diag.yaml',
#  '../results/active/xvector_2022-02-11/17-00-26/config_xvector_trimmed_2sec_plda_diag_offline_ahc_plda_sph.yaml',
#  '../results/active/clova_2022-02-12/14-34-45/config_clova_2sec_cos_emb_avg_offline_label_spread.yaml',
#  '../results/active/clova_2022-02-12/07-33-41/config_clova_2sec_cos_emb_avg_offline_kmeans.yaml',
#  '../results/active/clova_2022-02-12/08-57-35/config_clova_2sec_cos_emb_avg_offline_vb_plda_sph.yaml',
#  '../results/active/clova_2022-02-12/00-53-14/config_clova_2sec_cos_emb_avg_offline_ahc_plda_sph.yaml',
#  '../results/active/clova_2022-02-12/23-34-54/config_clova_2sec_cos_emb_avg.yaml',
#  '../results/active/clova_2022-02-11/16-51-26/config_clova_2sec_cos_emb_avg_offline_vb_plda_sph.yaml',
#  '../results/active/clova_2022-02-11/16-54-18/config_clova_2sec_score_plda_sph.yaml',
#  '../results/active/clova_2022-02-11/16-52-20/config_clova_2sec_cos_emb_avg_offline_label_spread.yaml',
#  '../results/active/clova_2022-02-11/16-52-27/config_clova_2sec_cos_emb_avg.yaml',
#  '../results/active/clova_2022-02-11/16-53-35/config_clova_2sec_score_cos_sc_avg.yaml',
#  '../results/active/clova_2022-02-11/16-51-00/config_clova_2sec_cos_emb_avg_offline_kmeans.yaml',
#  '../results/active/xvector_2022-02-13/10-37-30/config_xvector_trimmed_2sec_score_plda_diag_by-the-book.yaml',
#  '../results/active/xvector_2022-02-13/06-08-35/config_xvector_trimmed_2sec_plda_diag_offline_vb_plda_sph.yaml']

# %%
results_dict = {}

# %%
config_files = ['../results/active/clova_2022-02-12/14-34-45/config_clova_2sec_cos_emb_avg_offline_label_spread.yaml',
'../results/active/clova_2022-02-12/07-33-41/config_clova_2sec_cos_emb_avg_offline_kmeans.yaml',
'../results/active/clova_2022-02-12/08-57-35/config_clova_2sec_cos_emb_avg_offline_vb_plda_sph.yaml',
'../results/active/clova_2022-02-12/00-53-14/config_clova_2sec_cos_emb_avg_offline_ahc_plda_sph.yaml',
'../results/active/speechbrain_2022-02-11/23-31-34/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_kmeans.yaml',
'../results/active/speechbrain_2022-02-12/01-45-26/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_vb_plda_sph.yaml',
'../results/active/speechbrain_2022-02-12/07-24-25/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_label_spread.yaml',
'../results/active/speechbrain_2022-02-12/00-21-28/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_ahc_plda_sph.yaml',
'../results/active/xvector_2022-02-12/02-36-17/config_xvector_trimmed_2sec_plda_diag_offline_ahc_plda_sph.yaml',
'../results/active/xvector_2022-02-12/23-06-49/config_xvector_trimmed_2sec_plda_diag_offline_kmeans.yaml',
'../results/active/xvector_2022-02-13/06-08-35/config_xvector_trimmed_2sec_plda_diag_offline_vb_plda_sph.yaml', 
'../results/active/speechbrain_2022-02-11/23-31-34/config_speechbrain_trimmed_2sec_cos_emb_avg_offline_kmeans.yaml']

# %%
frr_point = 1



for config_file in tqdm(config_files):
    
    print(os.path.basename(config_file).split('.')[0])
    
    config_dir = os.path.dirname(config_file)
    config = yaml.load(open(config_file), Loader=yaml.FullLoader)
    
    embeddings_name = config["embeddings_name"] # ['clova', 'speechbrain', 'xvector']
    embeddings_type = config["embeddings_type"]

    score_type = config["score_type"] # ['cos_emb_avg', 'cos_sc_avg', 'plda_sph', 'plda_diag']
    by_the_book = config["by_the_book"] # plda scoring
    preprocessing_name = config["preprocessing_name"]
    recognizer = config["recognizer"] # ['exp_avg', 'memory'], use 'memory' for 'cos_sc_avg'
    #sequential_updates = config["sequential_updates"]
    
    params = config["params"]
    if isinstance(params, dict):
        algorithm = params.get("algorithm", ["centroid"])[0]
    else:
        algorithm = "centroid"

    #
        
    run_name = f"{embeddings_name}_{embeddings_type}_{score_type}_{algorithm}"
#     if not sequential_updates:
#         run_name = f"{run_name}_offline"
    if embeddings_name == "xvector" and by_the_book:
        run_name = f"{run_name}_by-the-book"
    print(run_name)
    
    
    FAR_known_list_noadapt = []
    FAR_unknown_list_noadapt = []
    EER_known_list_noadapt = []
    EER_unknown_list_noadapt = []
    
    
    FAR_known_list = []
    FAR_unknown_list = []
    EER_known_list = []
    EER_unknown_list = []
    
#     thresholds = []


    params_dict = {"alpha": [], "Fa": [], "Fb": [], "algorithm": [], "threshold": []}
    
    for results_dir_iter in [dir_name for dir_name in glob.glob(f"{config_dir}/*") if os.path.isdir(dir_name)]:
        #print(results_dir_iter)
        
        try:
            with open(f"{results_dir_iter}/params.pickle", "rb") as params_file:
                params = pickle.load(params_file)
            #print(params)
        except:
            print(f"Failed to load params for {results_dir_iter}")
            continue
            
            
#         thresholds += [params["threshold"]]
        
        for key in params_dict.keys():
            val = params.get(key, np.nan)
            val = val if val is not None else np.nan
            params_dict[key].append(val)
                

        try:
            scores_target_pooled = np.loadtxt(f"{results_dir_iter}/scores_tar.txt")
            scores_impostor_known_pooled = np.loadtxt(f"{results_dir_iter}/scores_imp.txt")
            scores_impostor_unknown_pooled = np.loadtxt(f"{results_dir_iter}/scores_imp_unk.txt")

            scores_target_pooled_enrich = np.loadtxt(f"{results_dir_iter}/scores_adapted_tar.txt")
            scores_impostor_known_pooled_enrich = np.loadtxt(f"{results_dir_iter}/scores_adapted_imp.txt")
            scores_impostor_unknown_pooled_enrich = np.loadtxt(f"{results_dir_iter}/scores_adapted_imp_unk.txt")
        except:
            print(f"Failed to load scores for {results_dir_iter}")
            continue
            
        # no adaptation
        scores, labels = utils.concatenate_with_labels(scores_impostor_known_pooled, scores_target_pooled)
        FAR_at_FRR_known, _ = metrics.far_at_frr(scores, labels, frr_point=frr_point)
        EER_known = metrics.eer(scores, labels)[0]*100

        scores, labels = utils.concatenate_with_labels(scores_impostor_unknown_pooled, scores_target_pooled)
        FAR_at_FRR_unknown, _ = metrics.far_at_frr(scores, labels, frr_point=frr_point)
        EER_unknown = metrics.eer(scores, labels)[0]*100
        
        FAR_known_list_noadapt += [FAR_at_FRR_known]
        FAR_unknown_list_noadapt += [FAR_at_FRR_unknown]
        EER_known_list_noadapt += [EER_known]
        EER_unknown_list_noadapt += [EER_unknown] 
        
    
        # adapted
        scores, labels = utils.concatenate_with_labels(scores_impostor_known_pooled_enrich, scores_target_pooled_enrich)
        FAR_at_FRR_known, _ = metrics.far_at_frr(scores, labels, frr_point=frr_point)
        EER_known = metrics.eer(scores, labels)[0]*100

        scores, labels = utils.concatenate_with_labels(scores_impostor_unknown_pooled_enrich, scores_target_pooled_enrich)
        FAR_at_FRR_unknown, _ = metrics.far_at_frr(scores, labels, frr_point=frr_point)
        EER_unknown = metrics.eer(scores, labels)[0]*100

        FAR_known_list += [FAR_at_FRR_known]
        FAR_unknown_list += [FAR_at_FRR_unknown]
        EER_known_list += [EER_known]
        EER_unknown_list += [EER_unknown]   
        
        
#     thresholds = np.array(thresholds)
#     alphas = np.array(alphas)

    FAR_known_list_noadapt = np.array(FAR_known_list_noadapt)
    FAR_unknown_list_noadapt = np.array(FAR_unknown_list_noadapt)
    EER_known_list_noadapt = np.array(EER_known_list_noadapt)
    EER_unknown_list_noadapt = np.array(EER_unknown_list_noadapt)
    
    FAR_known_list = np.array(FAR_known_list)
    FAR_unknown_list = np.array(FAR_unknown_list)
    EER_known_list = np.array(EER_known_list)
    EER_unknown_list = np.array(EER_unknown_list)
    
    
    results_dict_run = {}
    results_dict_run['FAR_known_noadapt'] = FAR_known_list_noadapt
    results_dict_run['FAR_unknown_noadapt'] = FAR_unknown_list_noadapt
    results_dict_run['EER_know_noadapt'] = EER_known_list_noadapt
    results_dict_run['EER_unknown_noadapt'] = EER_unknown_list_noadapt
    
    results_dict_run['FAR_known'] = FAR_known_list
    results_dict_run['FAR_unknown'] = FAR_unknown_list
    results_dict_run['EER_know'] = EER_known_list
    results_dict_run['EER_unknown'] = EER_unknown_list
    results_dict_run['params'] = params_dict
    
    for key, val in params_dict.items():
        params_dict[key] = np.array(val)
    
    
    # sort
    params_dict = results_dict_run['params']
    
    thresholds = params_dict['threshold']
    idx_sort = np.argsort(thresholds)
    
    for key, val in results_dict_run.items():
        if isinstance(val, np.ndarray):
            results_dict_run[key] = val[idx_sort]
        elif isinstance(val, dict):
            for k, v in val.items():
                if isinstance(v, np.ndarray):
                    val[k] = v[idx_sort]
                else:
                    print("Error")
                    
    results_dict[run_name] = results_dict_run
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# config_clova_2sec_cos_emb_avg_offline_label_spread
# clova_2sec_cos_emb_avg_label_spread
#   9%|▉         | 1/11 [01:42<17:06, 102.61s/it]
# config_clova_2sec_cos_emb_avg_offline_kmeans
# clova_2sec_cos_emb_avg_kmeans
#  18%|█▊        | 2/11 [03:20<14:57, 99.71s/it]
# config_clova_2sec_cos_emb_avg_offline_vb_plda_sph
# clova_2sec_cos_emb_avg_vb_plda_sph
#  27%|██▋       | 3/11 [21:01<1:11:49, 538.68s/it]
# config_clova_2sec_cos_emb_avg_offline_ahc_plda_sph
# clova_2sec_plda_sph_ahc_plda_sph
#  36%|███▋      | 4/11 [21:02<38:04, 326.42s/it]
# config_speechbrain_trimmed_2sec_cos_emb_avg_offline_kmeans
# speechbrain_trimmed_2sec_cos_emb_avg_kmeans
#  45%|████▌     | 5/11 [22:43<24:31, 245.28s/it]
# config_speechbrain_trimmed_2sec_cos_emb_avg_offline_vb_plda_sph
# speechbrain_trimmed_2sec_cos_emb_avg_vb_plda_sph
#  55%|█████▍    | 6/11 [40:15<43:18, 519.61s/it]
# config_speechbrain_trimmed_2sec_cos_emb_avg_offline_label_spread
# speechbrain_trimmed_2sec_cos_emb_avg_label_spread
#  64%|██████▎   | 7/11 [41:56<25:29, 382.49s/it]
# config_speechbrain_trimmed_2sec_cos_emb_avg_offline_ahc_plda_sph
# speechbrain_trimmed_2sec_plda_sph_ahc_plda_sph
#  73%|███████▎  | 8/11 [41:57<13:03, 261.02s/it]
# config_xvector_trimmed_2sec_plda_diag_offline_ahc_plda_sph
# xvector_trimmed_2sec_plda_diag_ahc_plda_diag_by-the-book
#  82%|████████▏ | 9/11 [41:57<05:59, 179.70s/it]
# config_xvector_trimmed_2sec_plda_diag_offline_kmeans
# xvector_trimmed_2sec_plda_diag_kmeans
#  91%|█████████ | 10/11 [43:38<02:35, 155.35s/it]
# config_xvector_trimmed_2sec_plda_diag_offline_vb_plda_sph
# xvector_trimmed_2sec_plda_diag_vb_plda_diag
# 100%|██████████| 11/11 [57:13<00:00, 312.13s/it]

# %%
results_dict.keys()
# Out:
# dict_keys(['speechbrain_trimmed_2sec_cos_emb_avg_kmeans'])

# %%
plt.figure(figsize=(8, 6))
plt.xlabel("threshold")
plt.ylabel("EER, %")
plt.xlim(-5, 10)
plt.ylim(2, 7)

for run_name in ['clova_2sec_cos_emb_avg_label_spread']: 
    
    results_dict_run = results_dict[run_name]
    params_dict = results_dict_run['params']
    
    thresholds = params_dict['threshold']
    alphas = params_dict['alpha']
    
    # w/o adaptation
    FAR_known_noadapt = results_dict_run['FAR_known_noadapt']
    FAR_unknown_noadapt = results_dict_run['FAR_unknown_noadapt']
    EER_known_noadapt = results_dict_run['EER_know_noadapt']
    EER_unknown_noadapt = results_dict_run['EER_unknown_noadapt']
    
    label = f"{run_name}_noadapt"
    plt.plot(thresholds[:], EER_known_noadapt[:], "k--", label=label);
    plt.legend()
    
    
    # w/ adaptation
    FAR_known = results_dict_run['FAR_known']
    FAR_unknown = results_dict_run['FAR_unknown']
    EER_known = results_dict_run['EER_know']
    EER_unknown = results_dict_run['EER_unknown']
    
    label = run_name
    plt.plot(thresholds[:], EER_known[:], label=label);
    plt.legend() 
    
  
    
#plt.savefig("NAME", bbox_inches="tight")

# %%
fig = plt.figure(figsize=(16, 6))
ax = fig.subplots(1, 2)
ax[0].set(xlabel="threshold", ylabel="EER, %")
ax[1].set(xlabel="threshold", ylabel="EER, %")
ax[0].set(xlim=(-5, 10))
ax[1].set(xlim=(-5, 10))
ax[0].set(ylim=(2, 7))
ax[1].set(ylim=(2, 7))
ax[0].set_title("EER, %, known")
ax[1].set_title("EER, %, unknown")


run_name = 'clova_2sec_cos_emb_avg_label_spread'

results_dict_run = results_dict[run_name]
params_dict = results_dict_run['params']

thresholds = params_dict['threshold']
alphas = params_dict['alpha']

# w/o adaptation
FAR_known_noadapt = results_dict_run['FAR_known_noadapt']
FAR_unknown_noadapt = results_dict_run['FAR_unknown_noadapt']
EER_known_noadapt = results_dict_run['EER_know_noadapt']
EER_unknown_noadapt = results_dict_run['EER_unknown_noadapt']

label = f"{run_name}_noadapt"
ax[0].plot(thresholds[:], EER_known_noadapt[:], "k--", label=label);
ax[0].legend();
ax[1].plot(thresholds[:], EER_unknown_noadapt[:], "k--", label=label);
ax[1].legend();    
    

# w/ adaptation
FAR_known = results_dict_run['FAR_known']
FAR_unknown = results_dict_run['FAR_unknown']
EER_known = results_dict_run['EER_know']
EER_unknown = results_dict_run['EER_unknown']

label = run_name
ax[0].plot(thresholds[:], EER_known[:], label=label);
ax[0].legend();

ax[1].plot(thresholds[:], EER_unknown[:], label=label);
ax[1].legend(); 


#plt.savefig("NAME", bbox_inches="tight")

# %%
results_dict.keys()
# Out:
# dict_keys(['clova_2sec_cos_emb_avg_label_spread', 'clova_2sec_cos_emb_avg_kmeans', 'clova_2sec_cos_emb_avg_vb_plda_sph', 'clova_2sec_plda_sph_ahc_plda_sph', 'speechbrain_trimmed_2sec_cos_emb_avg_vb_plda_sph', 'speechbrain_trimmed_2sec_cos_emb_avg_label_spread', 'speechbrain_trimmed_2sec_plda_sph_ahc_plda_sph', 'xvector_trimmed_2sec_plda_diag_ahc_plda_diag_by-the-book', 'xvector_trimmed_2sec_plda_diag_kmeans', 'xvector_trimmed_2sec_plda_diag_vb_plda_diag'])

# %%
fig = plt.figure(figsize=(16, 6))
ax = fig.subplots(1, 2)
ax[0].set(xlabel="threshold", ylabel="EER, %")
ax[1].set(xlabel="threshold", ylabel="EER, %")
ax[0].set(xlim=(-2, 10))
ax[1].set(xlim=(-2, 10))
ax[0].set(ylim=(2, 7))
ax[1].set(ylim=(2, 7))
ax[0].set_title("EER, known", fontsize = 15)
ax[1].set_title("EER, unknown", fontsize = 15)
tick_font = 15
ax[0].xaxis.get_label().set_fontsize(tick_font)
ax[0].yaxis.get_label().set_fontsize(tick_font)
ax[1].xaxis.get_label().set_fontsize(tick_font)
ax[1].yaxis.get_label().set_fontsize(tick_font)
ax[0].tick_params(axis='both', which='major', labelsize=10)
ax[1].tick_params(axis='both', which='major', labelsize=10)



fa = 0.1
fb = 1

run_name = 'clova_2sec_cos_emb_avg_vb_plda_sph'
    
results_dict_run = results_dict[run_name]
params_dict = results_dict_run['params']
Fa = params_dict["Fa"]
Fb = params_dict["Fb"]

mask = (Fa == fa) * (Fb == fb)

thresholds = params_dict['threshold']
#alphas = params_dict['alpha']

# w/o adaptation
FAR_known_noadapt = results_dict_run['FAR_known_noadapt']
FAR_unknown_noadapt = results_dict_run['FAR_unknown_noadapt']
EER_known_noadapt = results_dict_run['EER_know_noadapt']
EER_unknown_noadapt = results_dict_run['EER_unknown_noadapt']

label = f"{run_name}_noadapt"
ax[0].plot(thresholds[:], EER_known_noadapt[:], "k--", label=label);
ax[0].legend()
ax[1].plot(thresholds[:], EER_unknown_noadapt[:], "k--", label=label);
ax[1].legend()    
    

# w/ adaptation
FAR_known = results_dict_run['FAR_known']
FAR_unknown = results_dict_run['FAR_unknown']
EER_known = results_dict_run['EER_know']
EER_unknown = results_dict_run['EER_unknown']


mask_nan = np.isnan(alphas)
mask_num = np.logical_not(mask_nan)

label = f"{run_name}_Fa{fa:.2f}_Fb{fb:.2f}"

ax[0].plot(thresholds[mask], EER_known[mask], label=label);
ax[0].legend() 

ax[1].plot(thresholds[mask], EER_unknown[mask], label=label);
ax[1].legend() 

ax[0].grid() 
ax[1].grid() 


for run_name in ['clova_2sec_cos_emb_avg_label_spread',
                 'clova_2sec_cos_emb_avg_kmeans', 
                 'clova_2sec_plda_sph_ahc_plda_sph']:

    results_dict_run = results_dict[run_name]
    params_dict = results_dict_run['params']
    
    thresholds = params_dict['threshold']
    alphas = params_dict['alpha']
                
    FAR_known = results_dict_run['FAR_known']
    FAR_unknown = results_dict_run['FAR_unknown']
    EER_known = results_dict_run['EER_know']
    EER_unknown = results_dict_run['EER_unknown']


    mask_nan = np.isnan(alphas)
    mask_num = np.logical_not(mask_nan)

    label = run_name
    ax[0].plot(thresholds[mask_nan], EER_known[mask_nan], label=label);
    ax[0].legend() 

    ax[1].plot(thresholds[mask_nan], EER_unknown[mask_nan], label=label);
    ax[1].legend()

# %%
results_dict.keys()
# Out:
# dict_keys(['clova_2sec_cos_emb_avg_label_spread', 'clova_2sec_cos_emb_avg_kmeans', 'clova_2sec_cos_emb_avg_vb_plda_sph', 'clova_2sec_plda_sph_ahc_plda_sph', 'speechbrain_trimmed_2sec_cos_emb_avg_vb_plda_sph', 'speechbrain_trimmed_2sec_cos_emb_avg_label_spread', 'speechbrain_trimmed_2sec_plda_sph_ahc_plda_sph', 'xvector_trimmed_2sec_plda_diag_ahc_plda_diag_by-the-book', 'xvector_trimmed_2sec_plda_diag_kmeans', 'xvector_trimmed_2sec_plda_diag_vb_plda_diag', 'speechbrain_trimmed_2sec_cos_emb_avg_kmeans'])

# %%
fig = plt.figure(figsize=(16, 6))
ax = fig.subplots(1, 2)
ax[0].set(xlabel="threshold", ylabel="EER, %")
ax[1].set(xlabel="threshold", ylabel="EER, %")
ax[0].set(xlim=(-2, 8))
ax[1].set(xlim=(-2, 8))
ax[0].set(ylim=(3, 7))
ax[1].set(ylim=(3, 7))
ax[0].set_title("EER, known", fontsize = 15)
ax[1].set_title("EER, unknown", fontsize = 15)
tick_font = 15
ax[0].xaxis.get_label().set_fontsize(tick_font)
ax[0].yaxis.get_label().set_fontsize(tick_font)
ax[1].xaxis.get_label().set_fontsize(tick_font)
ax[1].yaxis.get_label().set_fontsize(tick_font)
ax[0].tick_params(axis='both', which='major', labelsize=10)
ax[1].tick_params(axis='both', which='major', labelsize=10)



fa = 0.3
fb = 1

run_name = 'speechbrain_trimmed_2sec_cos_emb_avg_vb_plda_sph'
    
results_dict_run = results_dict[run_name]
params_dict = results_dict_run['params']
Fa = params_dict["Fa"]
Fb = params_dict["Fb"]

mask = (Fa == fa) * (Fb == fb)

thresholds = params_dict['threshold']
alphas = params_dict['alpha']

# w/o adaptation
FAR_known_noadapt = results_dict_run['FAR_known_noadapt']
FAR_unknown_noadapt = results_dict_run['FAR_unknown_noadapt']
EER_known_noadapt = results_dict_run['EER_know_noadapt']
EER_unknown_noadapt = results_dict_run['EER_unknown_noadapt']

label = f"{run_name}_noadapt"
ax[0].plot(thresholds[:], EER_known_noadapt[:], "k--", label=label);
ax[0].legend()
ax[1].plot(thresholds[:], EER_unknown_noadapt[:], "k--", label=label);
ax[1].legend()    
    
ax[0].grid() 
ax[1].grid() 


# w/ adaptation
FAR_known = results_dict_run['FAR_known']
FAR_unknown = results_dict_run['FAR_unknown']
EER_known = results_dict_run['EER_know']
EER_unknown = results_dict_run['EER_unknown']


mask_nan = np.isnan(alphas)
mask_num = np.logical_not(mask_nan)

label = f"{run_name}_Fa{fa:.2f}_Fb{fb:.2f}"

ax[0].plot(thresholds[mask], EER_known[mask], label=label);
ax[0].legend() 

ax[1].plot(thresholds[mask], EER_unknown[mask], label=label);
ax[1].legend() 




for run_name in ['speechbrain_trimmed_2sec_cos_emb_avg_kmeans', 
                 'speechbrain_trimmed_2sec_cos_emb_avg_label_spread', 
                 'speechbrain_trimmed_2sec_plda_sph_ahc_plda_sph']:

    results_dict_run = results_dict[run_name]
    params_dict = results_dict_run['params']
    
    thresholds = params_dict['threshold']
    alphas = params_dict['alpha']
                
    FAR_known = results_dict_run['FAR_known']
    FAR_unknown = results_dict_run['FAR_unknown']
    EER_known = results_dict_run['EER_know']
    EER_unknown = results_dict_run['EER_unknown']


    mask_nan = np.isnan(alphas)
    mask_num = np.logical_not(mask_nan)

    label = run_name
    ax[0].plot(thresholds[mask_nan], EER_known[mask_nan], label=label);
    ax[0].legend() 

    ax[1].plot(thresholds[mask_nan], EER_unknown[mask_nan], label=label);
    ax[1].legend()

# %%
results_dict.keys()
# Out:
# dict_keys(['clova_2sec_cos_emb_avg_label_spread', 'clova_2sec_cos_emb_avg_kmeans', 'clova_2sec_cos_emb_avg_vb_plda_sph', 'clova_2sec_plda_sph_ahc_plda_sph', 'speechbrain_trimmed_2sec_cos_emb_avg_vb_plda_sph', 'speechbrain_trimmed_2sec_cos_emb_avg_label_spread', 'speechbrain_trimmed_2sec_plda_sph_ahc_plda_sph', 'xvector_trimmed_2sec_plda_diag_ahc_plda_diag_by-the-book', 'xvector_trimmed_2sec_plda_diag_kmeans', 'xvector_trimmed_2sec_plda_diag_vb_plda_diag', 'speechbrain_trimmed_2sec_cos_emb_avg_kmeans'])

# %%
fig = plt.figure(figsize=(16, 6))
ax = fig.subplots(1, 2)
ax[0].set(xlabel="threshold", ylabel="EER, %")
ax[1].set(xlabel="threshold", ylabel="EER, %")
ax[0].set(xlim=(-0, 20))
ax[1].set(xlim=(-0, 20))
ax[0].set_title("EER, known", fontsize = 15)
ax[1].set_title("EER, unknown", fontsize = 15)
tick_font = 15
ax[0].xaxis.get_label().set_fontsize(tick_font)
ax[0].yaxis.get_label().set_fontsize(tick_font)
ax[1].xaxis.get_label().set_fontsize(tick_font)
ax[1].yaxis.get_label().set_fontsize(tick_font)
ax[0].tick_params(axis='both', which='major', labelsize=10)
ax[1].tick_params(axis='both', which='major', labelsize=10)




fa = 0.3
fb = 1

run_name = 'xvector_trimmed_2sec_plda_diag_vb_plda_diag'
    
results_dict_run = results_dict[run_name]
params_dict = results_dict_run['params']
Fa = params_dict["Fa"]
Fb = params_dict["Fb"]

mask = (Fa == fa) * (Fb == fb)

thresholds = params_dict['threshold']
alphas = params_dict['alpha']

# w/o adaptation
FAR_known_noadapt = results_dict_run['FAR_known_noadapt']
FAR_unknown_noadapt = results_dict_run['FAR_unknown_noadapt']
EER_known_noadapt = results_dict_run['EER_know_noadapt']
EER_unknown_noadapt = results_dict_run['EER_unknown_noadapt']

label = f"{run_name}_noadapt"
ax[0].plot(thresholds[:], EER_known_noadapt[:], "k--", label=label);
ax[0].legend()
ax[1].plot(thresholds[:], EER_unknown_noadapt[:], "k--", label=label);
ax[1].legend()    

ax[0].grid() 
ax[1].grid() 

# w/ adaptation
if False:
    
    FAR_known = results_dict_run['FAR_known']
    FAR_unknown = results_dict_run['FAR_unknown']
    EER_known = results_dict_run['EER_know']
    EER_unknown = results_dict_run['EER_unknown']


    mask_nan = np.isnan(alphas)
    mask_num = np.logical_not(mask_nan)

    label = f"{run_name}_Fa{fa:.2f}_Fb{fb:.2f}"

    ax[0].plot(thresholds[mask], EER_known[mask], label=label);
    ax[0].legend() 

    ax[1].plot(thresholds[mask], EER_unknown[mask], label=label);
    ax[1].legend() 




# for run_name in ['xvector_trimmed_2sec_plda_diag_centroid', 
#                  'xvector_trimmed_2sec_plda_diag_centroid_by-the-book', 
#                  'xvector_trimmed_2sec_plda_diag_kmeans', 
#                  'xvector_trimmed_2sec_plda_diag_ahc_plda_diag']:
    
for run_name in ['xvector_trimmed_2sec_plda_diag_ahc_plda_diag_by-the-book', 
                 'xvector_trimmed_2sec_plda_diag_kmeans']:

    results_dict_run = results_dict[run_name]
    params_dict = results_dict_run['params']
    
    thresholds = params_dict['threshold']
    alphas = params_dict['alpha']
                
    FAR_known = results_dict_run['FAR_known']
    FAR_unknown = results_dict_run['FAR_unknown']
    EER_known = results_dict_run['EER_know']
    EER_unknown = results_dict_run['EER_unknown']


    mask_nan = np.isnan(alphas)
    mask_num = np.logical_not(mask_nan)

    label = run_name
    ax[0].plot(thresholds[mask_nan], EER_known[mask_nan], label=label);
    ax[0].legend() 

    ax[1].plot(thresholds[mask_nan], EER_unknown[mask_nan], label=label);
    ax[1].legend()
